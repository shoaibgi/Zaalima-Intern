# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/PCB dataset/dataset-pcb.zip" -d /content/
# Out:
# Archive:  /content/drive/MyDrive/PCB dataset/dataset-pcb.zip
#    creating: /content/dataset-pcb/
#    creating: /content/dataset-pcb/images/
#    creating: /content/dataset-pcb/images/train/
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_06.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_07.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_08.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_09.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_12.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_13.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17822, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 17822 (delta 15), reused 6 (delta 6), pack-reused 17794 (from 3)
# Receiving objects: 100% (17822/17822), 17.01 MiB | 14.90 MiB/s, done.
# Resolving deltas: 100% (12146/12146), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data dataset.yaml --weights yolov5s.pt --cache --name pcb_1st --device=0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-02-21 15:54:38.943161: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771689278.963725   10276 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771689278.970460   10276 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771689278.988223   10276 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
